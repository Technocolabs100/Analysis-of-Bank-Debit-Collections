# %% [markdown]
# <a href="https://colab.research.google.com/github/anas1IA/Analysis-of-Bank-Debit-Collections/blob/main/Data/scarpe_from_youtube.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_api = "AIzaSyC3mSypuaR1Cc6m366BS8e5D5UWWTldt9Y"

# %%
#!pip install google-api-python-client

# %%
from googleapiclient.discovery import build
import numpy as np
import pandas as pd

# %%
api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = my_api

youtube = build(api_service_name, api_version, developerKey=DEVELOPER_KEY)

# %%
cols = ["videoId", "authorChannelId", "authorDisplayName", "textDisplay",
          "textOriginal", "publishedAt", "updatedAt","likeCount", "canReply" ,"totalReplyCount"]

# %%
def comment(item):
  item1 = item["snippet"]

  snippet = item1["topLevelComment"]["snippet"]

  for col in cols:
    try:
      if col in ("canReply","totalReplyCount"):
        data_dict[col].append(item1[col])
      else:
        s = snippet[col]
        if s != None and s != 'none':
          if col == "authorChannelId":
            data_dict[col].append(s["value"])
          else:
            data_dict[col].append(s)

        else:
          data_dict[col].append(np.nan)
    except Exception as e:
      data_dict[col].append(np.nan)
      raise e

  return data_dict

# %%
video_id = "17bzlWIGH3g"

# %%
data_dict = {col : [] for col in cols}

request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        textFormat="plainText",
        maxResults=10000,
        order='time'
    )

response = request.execute()
while response:
    for item in response["items"]:
      data_dict = comment(item)
    if 'nextPageToken' in response:
        request = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            textFormat="plainText",
            maxResults=10000,
            order='time',
            pageToken=response['nextPageToken']
        )
        response = request.execute()
    else:
        break

# %%
data = pd.DataFrame(data_dict)

# %%
data
# Out:
#          videoId           authorChannelId authorDisplayName  \
# 0    17bzlWIGH3g  UCfQOzgNxhofa3tLytH7Il2A  Berti Ballermann
# 1    17bzlWIGH3g  UCjI_66LbnMitzvRBKjxJ52A   Mansour Bendago
# 2    17bzlWIGH3g  UCUi09HLDL3ffzdGSXEEkYyQ     SKYWalkers SG
# 3    17bzlWIGH3g  UCXcbDED12gZgh4xhPeKnd0g    Mark Sandsmith
# 4    17bzlWIGH3g  UCO-QERAAgOuJeCarlI-1y0g          kaloncar
# ..           ...                       ...               ...
# 619  17bzlWIGH3g  UCgtNguQsXZhn1xrCW8xkesw   Marshall Bishop
# 620  17bzlWIGH3g  UC_B7zrshApEsBFL9p8dm1HQ        Matt Dugas
# 621  17bzlWIGH3g  UC_B7zrshApEsBFL9p8dm1HQ        Matt Dugas
# 622  17bzlWIGH3g  UCfW9c0r5vMbXcO8T3mNV-ow      Bo Deutscher
# 623  17bzlWIGH3g  UCWbv7YKHBjggIZEQgwM2JQg         Donna T63
#
#                                            textDisplay  \
# 0    I loved Prof. Lennox's explanation of narrow A...
# 1    Last segment is controversial as he is trying ...
# 2    "trust the science" is a most unscientific phrase
# 3                       Next time interview an expert.
# 4    Thank you John Anderson and John Lennox.   I c...
# ..                                                 ...
# 619  Great conversation. These guys might want to r...
# 620                           Family a fact or belief?
# 621            If Mother’s Earth 🌎, who’s your Daddy!?
# 622  This guy is a legend I can’t wait to watch thi...
# 623  Best man on earth to interview. Love it!! Than...
#
#                                           textOriginal           publishedAt  \
# 0    I loved Prof. Lennox's explanation of narrow A...  2023-04-07T15:59:58Z
# 1    Last segment is controversial as he is trying ...  2023-04-07T14:16:06Z
# 2    "trust the science" is a most unscientific phrase  2023-04-07T13:13:40Z
# 3                       Next time interview an expert.  2023-04-07T10:32:24Z
# 4    Thank you John Anderson and John Lennox.   I c...  2023-04-07T09:52:52Z
# ..                                                 ...                   ...
# 619  Great conversation. These guys might want to r...  2022-08-05T05:03:35Z
# 620                           Family a fact or belief?  2022-08-05T04:33:10Z
# 621            If Mother’s Earth 🌎, who’s your Daddy!?  2022-08-05T04:29:16Z
# 622  This guy is a legend I can’t wait to watch thi...  2022-08-05T04:04:05Z
# 623  Best man on earth to interview. Love it!! Than...  2022-08-05T04:02:35Z
#
#                 updatedAt  likeCount  canReply  totalReplyCount
# 0    2023-04-07T15:59:58Z          0      True                0
# 1    2023-04-07T14:16:06Z          0      True                0
# 2    2023-04-07T13:13:40Z          0      True                0
# 3    2023-04-07T10:32:24Z          0      True                0
# 4    2023-04-07T09:52:52Z          0      True                0
# ..                    ...        ...       ...              ...
# 619  2022-08-05T05:03:35Z          3      True                3
# 620  2022-08-05T04:33:10Z          0      True                0
# 621  2022-08-05T04:29:16Z          1      True                4
# 622  2022-08-05T04:04:05Z         33      True                1
# 623  2022-08-05T04:02:35Z         26      True                0
#
# [624 rows x 10 columns]
