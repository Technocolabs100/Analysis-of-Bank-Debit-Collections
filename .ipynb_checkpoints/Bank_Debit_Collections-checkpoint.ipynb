# %%
# modules we will use
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

#set style for the graph plots
sns.set_style("dark")

# read in our data
bank_filepath = "bank_data.csv"
bank_data = pd.read_csv(bank_filepath)

#set seed for reproducibility
np.random.seed(0)

# %%
bank_data
# Out:
#         id  expected_recovery_amount  actual_recovery_amount  \
# 0     2030                       194              263.540000
# 1     1150                       486              416.090000
# 2      380                       527              429.350000
# 3     1838                       536              296.990000
# 4     1995                       541              346.385000
# ...    ...                       ...                     ...
# 1877   361                      9785            15388.195990
# 1878   196                      9857             9709.909257
# 1879   313                      9859            30209.181790
# 1880  1781                      9920            20386.232190
# 1881   522                      9964            16706.305920
#
#      recovery_strategy  age     sex
# 0     Level 0 Recovery   19    Male
# 1     Level 0 Recovery   25  Female
# 2     Level 0 Recovery   27    Male
# 3     Level 0 Recovery   25    Male
# 4     Level 0 Recovery   34    Male
# ...

# %%
#check for NaN under an entire DataFrame
bank_data.isnull().values.any()
# Out:
# False

# %%
sns.scatterplot(x=bank_data['age'], y=bank_data['expected_recovery_amount'], hue=bank_data['recovery_strategy'])
plt.ylim(0, 2000)
plt.show()

# %%
#average age of customers just above and below the threshold
average_age = bank_data[(bank_data['expected_recovery_amount'] > 900) & (bank_data['expected_recovery_amount'] < 1100)]['age'].mean()
round(average_age)
# Out:
# 28

# %%
sns.scatterplot(x=bank_data['sex'], y=bank_data['expected_recovery_amount'])
plt.ylim(900, 1100)
plt.show()

# %%
# filter the dataframe to include only males
males_df = bank_data[bank_data['sex'] == 'Male']
# filter the males_df to include only rows with 'expected_recovery_amount' < 1000
filtered_male_df = males_df[(males_df['expected_recovery_amount'] > 900) & (males_df['expected_recovery_amount'] < 1100)]
# calculate the percentage
total_males = males_df.shape[0]
percentage = round((filtered_male_df.shape[0] / total_males) * 100, 2)
percentage
# Out:
# 11.31

# %%
sns.scatterplot(x=bank_data['actual_recovery_amount'], y=bank_data['expected_recovery_amount'])
plt.ylim(900, 1100)
plt.show()

# %%
sns.scatterplot(x=bank_data['actual_recovery_amount'], y=bank_data['expected_recovery_amount'])
plt.ylim(950, 1050)
plt.show()
